# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from scipy.sparse import coo_matrix

from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE

from tensorflow.python.ops import array_ops
from tensorflow.python.framework import dtypes
from tensorflow.python.framework import sparse_tensor
from tensorflow.python.ops import sparse_ops
from tensorflow.contrib.factorization.python.ops import factorization_ops
from tensorflow.contrib.factorization.python.ops import factorization_ops_test_utils

import tensorflow as tf
import pandas as pd
import numpy as np
import math
import os

def get_MAE(output_row, output_col, actual):
    mae = 0
    for i in range(actual.data.shape[0]):
        row_pred = output_row[actual.row[i]]
        col_pred = output_col[actual.col[i]]
        mae += abs(actual.data[i] - np.dot(row_pred, col_pred))
    mae /= actual.data.shape[0]
    return mae

def get_RMSE(output_row, output_col, actual):
    mse = 0
    for i in range(actual.data.shape[0]):
        row_pred = output_row[actual.row[i]]
        col_pred = output_col[actual.col[i]]
        err = actual.data[i] - np.dot(row_pred, col_pred)
        mse += err * err
    mse /= actual.data.shape[0]
    rmse = math.sqrt(mse)
    return rmse

def evaluate_model(sess, train_sparse, test_sparse, row_factor, col_factor):

    train_rmse = get_RMSE(row_factor, col_factor, train_sparse)
    test_rmse = get_RMSE(row_factor, col_factor, test_sparse)    

#     print('train RMSE: ', train_rmse)
#     print('test RMSE: ', test_rmse)
    tf.logging.info('train RMSE = %f' % train_rmse)
    tf.logging.info('test RMSE = %f' % test_rmse)

    train_mae = get_MAE(row_factor, col_factor, train_sparse)
    test_mae = get_MAE(row_factor, col_factor, test_sparse)    
#     print('train MAE: ', train_mae)
#     print('test MAE: ', test_mae)

    tf.logging.info('train MAE = %f' % train_mae)
    tf.logging.info('test MAE = %f' % test_mae)

# %%
headers = ['userId', 'movieId', 'rating', 'timestamp']
ratings_df = pd.read_csv('../datasets/u.data', names=headers, header=None, sep="\t", 
                         dtype={'userId': np.int32, 'movieId': np.int32, 
                                'rating': np.float32,'timestamp': np.int32,
                         })

# %%
print("\nData Preprocessing....\n")

np_users = ratings_df.userId.values
np_items = ratings_df.movieId.values

unique_users = np.unique(np_users)
unique_items = np.unique(np_items)

n_users = unique_users.shape[0]
n_items = unique_items.shape[0]

print(n_users, n_items)

max_item = unique_items[-1]
max_user = unique_items[-1]

# Reconstruct the ratings set's user/movie indices

# Mapping unique users down to an array 0..n_users-1
z = np.zeros(max_user+1, dtype=int)
z[unique_users] = np.arange(n_users)
users_map = z[np_users]

# Mapping unique items down to an array 0..n_items-1
z = np.zeros(max_item+1, dtype=int)
z[unique_items] = np.arange(n_items)
movies_map = z[np_items]

np_ratings = ratings_df.rating.values
ratings = np.zeros((np_ratings.shape[0], 3), dtype=object)
ratings[:, 0] = users_map
print(users_map)
ratings[:, 1] = movies_map
ratings[:, 2] = np_ratings
# Out:
# Data Preprocessing....
#
# 943 1682
# [195 185  21 ... 275  12  11]

# %%
X_train, X_test = train_test_split(ratings, train_size=0.9)

# Ignoring timestamp
user_train, movie_train, rating_train = zip(*X_train)
train_sparse = coo_matrix((rating_train, (user_train, movie_train)), shape=(n_users, n_items))
# print(train_sparse)

user_test, movie_test, rating_test = zip(*X_test)
test_sparse = coo_matrix((rating_test, (user_test, movie_test)), shape=(n_users, n_items))

# %%
# Default hyperparameters
DEFAULT_PARAMS = {
    'weights': True,
    'latent_factors': 5,
    'num_iters': 20,
    'regularization': 0.07,
    'unobs_weight': 0.01,
    'wt_type': 0,
    'feature_wt_factor': 130.0,
    'feature_wt_exp': 0.08,
    'delimiter': '\t'
}

# Parameters optimized with hypertuning for the MovieLens data set
OPTIMIZED_PARAMS = {
    'latent_factors': 34,
    'regularization': 9.83,
    'unobs_weight': 0.001,
    'feature_wt_factor': 189.8,
}

LOG_RATINGS = 0
LINEAR_RATINGS = 1
LINEAR_OBS_W = 100.0

params = OPTIMIZED_PARAMS

# Create WALS model
num_rows = train_sparse.shape[0]
num_cols = train_sparse.shape[1]

row_wts = np.ones(num_rows)
    
p = (train_sparse > 0.0).sum(0)
p = p.astype("float32")
p[p==0] = 0.0001
frac = np.array(1.0/p)
frac[np.ma.masked_invalid(frac).mask] = 0.0

col_wts = np.array(params['feature_wt_factor'] * frac).flatten()
assert np.isfinite(col_wts).sum() == col_wts.shape[0]

row_factor = None
col_factor = None

indices = np.array([[i,j] for i,j in zip(train_sparse.row, train_sparse.col)])
values = np.asarray(train_sparse.data, dtype=np.float32)
shape = np.asarray([train_sparse.shape[0], train_sparse.shape[1]], dtype=np.int64)
# print(indices); print(values); print(shape)

input_tensor = tf.SparseTensor(indices=indices, values=values, dense_shape=shape)

model = factorization_ops.WALSModel(num_rows, num_cols, 
                                    n_components=params['latent_factors'], 
                                    unobserved_weight=params['unobs_weight'],
                                    regularization=params['regularization'],
                                    row_weights=row_wts, 
                                    col_weights=col_wts)

# Retrieve the row and column factors
row_factor = model.row_factors[0]
col_factor = model.col_factors[0]

# %%
print("\nTraining....\n")

sess = tf.Session(graph=input_tensor.graph)

row_update_op = model.update_row_factors(sp_input=input_tensor)[1]
col_update_op = model.update_col_factors(sp_input=input_tensor)[1]

sess.run(model.initialize_op)
sess.run(model.worker_init)

row_update_prep_gramian_op = model.row_update_prep_gramian_op
col_update_prep_gramian_op = model.col_update_prep_gramian_op

init_row_update_op = model.initialize_row_update_op
init_col_update_op = model.initialize_col_update_op

num_iterations = 100

for i in range(num_iterations):    
    row_update_prep_gramian_op.run(session=sess)
    init_row_update_op.run(session=sess)
    row_update_op.run(session=sess)
    
    col_update_prep_gramian_op.run(session=sess)
    init_col_update_op.run(session=sess)
    col_update_op.run(session=sess)
        
    print("\nEvaluating..: ", i, "/", num_iterations)
    output_row = row_factor.eval(session=sess)
    output_col = col_factor.eval(session=sess)
    evaluate_model(sess, train_sparse, test_sparse, output_row, output_col)
# Out:
# Training....
#
#
# Evaluating..:  0 / 100
# INFO:tensorflow:train RMSE = 1.621486
# INFO:tensorflow:test RMSE = 2.282442
# INFO:tensorflow:train MAE = 1.243031
# INFO:tensorflow:test MAE = 1.806128
#
# Evaluating..:  1 / 100
# INFO:tensorflow:train RMSE = 0.733191
# INFO:tensorflow:test RMSE = 1.130968
# INFO:tensorflow:train MAE = 0.568840
# INFO:tensorflow:test MAE = 0.883746
#
# Evaluating..:  2 / 100
# INFO:tensorflow:train RMSE = 0.655005
# INFO:tensorflow:test RMSE = 1.073729
# INFO:tensorflow:train MAE = 0.502726
# INFO:tensorflow:test MAE = 0.841246
#
# Evaluating..:  3 / 100
# INFO:tensorflow:train RMSE = 0.624933
# INFO:tensorflow:test RMSE = 1.059260
# INFO:tensorflow:train MAE = 0.476203
# INFO:tensorflow:test MAE = 0.829488
#
# Evaluating..:  4 / 100
# INFO:tensorflow:train RMSE = 0.607336
# INFO:tensorflow:test RMSE = 1.052847
# INFO:tensorflow:train MAE = 0.460346
# INFO:tensorflow:test MAE = 0.823999
#
# Evaluating..:  5 / 100
# INFO:tensorflow:train RMSE = 0.595453
# INFO:tensorflow:test RMSE = 1.048687
# INFO:tensorflow:train MAE = 0.449529
# INFO:tensorflow:test MAE = 0.820193
#
# Evaluating..:  6 / 100
# INFO:tensorflow:train RMSE = 0.586788
# INFO:tensorflow:test RMSE = 1.045564
# INFO:tensorflow:train MAE = 0.441609
# INFO:tensorflow:test MAE = 0.817023
#
# Evaluating..:  7 / 100
# INFO:tensorflow:train RMSE = 0.580129
# INFO:tensorflow:test RMSE = 1.043098
# INFO:tensorflow:train MAE = 0.435478
# INFO:tensorflow:test MAE = 0.814577
#
# Evaluating..:  8 / 100
# INFO:tensorflow:train RMSE = 0.574821
# INFO:tensorflow:test RMSE = 1.041086
# INFO:tensorflow:train MAE = 0.430557
# INFO:tensorflow:test MAE = 0.812690
#
# Evaluating..:  9 / 100
# INFO:tensorflow:train RMSE = 0.570494
# INFO:tensorflow:test RMSE = 1.039406
# INFO:tensorflow:train MAE = 0.426533
# INFO:tensorflow:test MAE = 0.811273
#
# Evaluating..:  10 / 100
# INFO:tensorflow:train RMSE = 0.566917
# INFO:tensorflow:test RMSE = 1.037984
# INFO:tensorflow:train MAE = 0.423193
# INFO:tensorflow:test MAE = 0.810157
#
# Evaluating..:  11 / 100
# INFO:tensorflow:train RMSE = 0.563924
# INFO:tensorflow:test RMSE = 1.036777
# INFO:tensorflow:train MAE = 0.420364
# INFO:tensorflow:test MAE = 0.809168
#
# Evaluating..:  12 / 100
# INFO:tensorflow:train RMSE = 0.561388
# INFO:tensorflow:test RMSE = 1.035757
# INFO:tensorflow:train MAE = 0.417951
# INFO:tensorflow:test MAE = 0.808323
#
# Evaluating..:  13 / 100
# INFO:tensorflow:train RMSE = 0.559213
# INFO:tensorflow:test RMSE = 1.034903
# INFO:tensorflow:train MAE = 0.415860
# INFO:tensorflow:test MAE = 0.807617
#
# Evaluating..:  14 / 100
# INFO:tensorflow:train RMSE = 0.557321
# INFO:tensorflow:test RMSE = 1.034198
# INFO:tensorflow:train MAE = 0.414025
# INFO:tensorflow:test MAE = 0.807000
#
# Evaluating..:  15 / 100
# INFO:tensorflow:train RMSE = 0.555656
# INFO:tensorflow:test RMSE = 1.033626
# INFO:tensorflow:train MAE = 0.412417
# INFO:tensorflow:test MAE = 0.806493
#
# Evaluating..:  16 / 100
# INFO:tensorflow:train RMSE = 0.554175
# INFO:tensorflow:test RMSE = 1.033167
# INFO:tensorflow:train MAE = 0.410985
# INFO:tensorflow:test MAE = 0.806001
#
# Evaluating..:  17 / 100
# INFO:tensorflow:train RMSE = 0.552846
# INFO:tensorflow:test RMSE = 1.032804
# INFO:tensorflow:train MAE = 0.409689
# INFO:tensorflow:test MAE = 0.805507
#
# Evaluating..:  18 / 100
# INFO:tensorflow:train RMSE = 0.551645
# INFO:tensorflow:test RMSE = 1.032519
# INFO:tensorflow:train MAE = 0.408510
# INFO:tensorflow:test MAE = 0.805061
#
# Evaluating..:  19 / 100
# INFO:tensorflow:train RMSE = 0.550553
# INFO:tensorflow:test RMSE = 1.032302
# INFO:tensorflow:train MAE = 0.407421
# INFO:tensorflow:test MAE = 0.804657
#
# Evaluating..:  20 / 100
# INFO:tensorflow:train RMSE = 0.549556
# INFO:tensorflow:test RMSE = 1.032141
# INFO:tensorflow:train MAE = 0.406430
# INFO:tensorflow:test MAE = 0.804232
#
# Evaluating..:  21 / 100
# INFO:tensorflow:train RMSE = 0.548641
# INFO:tensorflow:test RMSE = 1.032032
# INFO:tensorflow:train MAE = 0.405516
# INFO:tensorflow:test MAE = 0.803823
#
# Evaluating..:  22 / 100
# INFO:tensorflow:train RMSE = 0.547800
# INFO:tensorflow:test RMSE = 1.031970
# INFO:tensorflow:train MAE = 0.404671
# INFO:tensorflow:test MAE = 0.803372
#
# Evaluating..:  23 / 100
# INFO:tensorflow:train RMSE = 0.547023
# INFO:tensorflow:test RMSE = 1.031952
# INFO:tensorflow:train MAE = 0.403893
# INFO:tensorflow:test MAE = 0.802922
#
# Evaluating..:  24 / 100
# INFO:tensorflow:train RMSE = 0.546304
# INFO:tensorflow:test RMSE = 1.031975
# INFO:tensorflow:train MAE = 0.403173
# INFO:tensorflow:test MAE = 0.802499
#
# Evaluating..:  25 / 100
# INFO:tensorflow:train RMSE = 0.545638
# INFO:tensorflow:test RMSE = 1.032036
# INFO:tensorflow:train MAE = 0.402501
# INFO:tensorflow:test MAE = 0.802176
#
# Evaluating..:  26 / 100
# INFO:tensorflow:train RMSE = 0.545020
# INFO:tensorflow:test RMSE = 1.032132
# INFO:tensorflow:train MAE = 0.401873
# INFO:tensorflow:test MAE = 0.801925
#
# Evaluating..:  27 / 100
# INFO:tensorflow:train RMSE = 0.544447
# INFO:tensorflow:test RMSE = 1.032259
# INFO:tensorflow:train MAE = 0.401288
# INFO:tensorflow:test MAE = 0.801719
#
# Evaluating..:  28 / 100
# INFO:tensorflow:train RMSE = 0.543916
# INFO:tensorflow:test RMSE = 1.032413
# INFO:tensorflow:train MAE = 0.400744
# INFO:tensorflow:test MAE = 0.801537
#
# Evaluating..:  29 / 100
# INFO:tensorflow:train RMSE = 0.543423
# INFO:tensorflow:test RMSE = 1.032591
# INFO:tensorflow:train MAE = 0.400246
# INFO:tensorflow:test MAE = 0.801408
#
# Evaluating..:  30 / 100
# INFO:tensorflow:train RMSE = 0.542968
# INFO:tensorflow:test RMSE = 1.032789
# INFO:tensorflow:train MAE = 0.399780
# INFO:tensorflow:test MAE = 0.801359
#
# Evaluating..:  31 / 100
# INFO:tensorflow:train RMSE = 0.542546
# INFO:tensorflow:test RMSE = 1.033004
# INFO:tensorflow:train MAE = 0.399350
# INFO:tensorflow:test MAE = 0.801353
#
# Evaluating..:  32 / 100
# INFO:tensorflow:train RMSE = 0.542155
# INFO:tensorflow:test RMSE = 1.033234
# INFO:tensorflow:train MAE = 0.398949
# INFO:tensorflow:test MAE = 0.801385
#
# Evaluating..:  33 / 100
# INFO:tensorflow:train RMSE = 0.541794
# INFO:tensorflow:test RMSE = 1.033476
# INFO:tensorflow:train MAE = 0.398577
# INFO:tensorflow:test MAE = 0.801429
#
# Evaluating..:  34 / 100
# INFO:tensorflow:train RMSE = 0.541460
# INFO:tensorflow:test RMSE = 1.033726
# INFO:tensorflow:train MAE = 0.398230
# INFO:tensorflow:test MAE = 0.801486
#
# Evaluating..:  35 / 100
# INFO:tensorflow:train RMSE = 0.541151
# INFO:tensorflow:test RMSE = 1.033983
# INFO:tensorflow:train MAE = 0.397906
# INFO:tensorflow:test MAE = 0.801568
#
# Evaluating..:  36 / 100
# INFO:tensorflow:train RMSE = 0.540865
# INFO:tensorflow:test RMSE = 1.034245
# INFO:tensorflow:train MAE = 0.397601
# INFO:tensorflow:test MAE = 0.801675
#
# Evaluating..:  37 / 100
# INFO:tensorflow:train RMSE = 0.540599
# INFO:tensorflow:test RMSE = 1.034508
# INFO:tensorflow:train MAE = 0.397313
# INFO:tensorflow:test MAE = 0.801804
#
# Evaluating..:  38 / 100
# INFO:tensorflow:train RMSE = 0.540352
# INFO:tensorflow:test RMSE = 1.034772
# INFO:tensorflow:train MAE = 0.397042
# INFO:tensorflow:test MAE = 0.801961
#
# Evaluating..:  39 / 100
# INFO:tensorflow:train RMSE = 0.540122
# INFO:tensorflow:test RMSE = 1.035034
# INFO:tensorflow:train MAE = 0.396786
# INFO:tensorflow:test MAE = 0.802118
#
# Evaluating..:  40 / 100
# INFO:tensorflow:train RMSE = 0.539907
# INFO:tensorflow:test RMSE = 1.035293
# INFO:tensorflow:train MAE = 0.396544
# INFO:tensorflow:test MAE = 0.802287
#
# Evaluating..:  41 / 100
# INFO:tensorflow:train RMSE = 0.539707
# INFO:tensorflow:test RMSE = 1.035547
# INFO:tensorflow:train MAE = 0.396314
# INFO:tensorflow:test MAE = 0.802461
#
# Evaluating..:  42 / 100
# INFO:tensorflow:train RMSE = 0.539519
# INFO:tensorflow:test RMSE = 1.035795
# INFO:tensorflow:train MAE = 0.396096
# INFO:tensorflow:test MAE = 0.802652
#
# Evaluating..:  43 / 100
# INFO:tensorflow:train RMSE = 0.539343
# INFO:tensorflow:test RMSE = 1.036037
# INFO:tensorflow:train MAE = 0.395892
# INFO:tensorflow:test MAE = 0.802865
#
# Evaluating..:  44 / 100
# INFO:tensorflow:train RMSE = 0.539178
# INFO:tensorflow:test RMSE = 1.036272
# INFO:tensorflow:train MAE = 0.395703
# INFO:tensorflow:test MAE = 0.803072
#
# Evaluating..:  45 / 100
# INFO:tensorflow:train RMSE = 0.539022
# INFO:tensorflow:test RMSE = 1.036499
# INFO:tensorflow:train MAE = 0.395524
# INFO:tensorflow:test MAE = 0.803275
#
# Evaluating..:  46 / 100
# INFO:tensorflow:train RMSE = 0.538875
# INFO:tensorflow:test RMSE = 1.036718
# INFO:tensorflow:train MAE = 0.395356
# INFO:tensorflow:test MAE = 0.803472
#
# Evaluating..:  47 / 100
# INFO:tensorflow:train RMSE = 0.538736
# INFO:tensorflow:test RMSE = 1.036929
# INFO:tensorflow:train MAE = 0.395198
# INFO:tensorflow:test MAE = 0.803679
#
# Evaluating..:  48 / 100
# INFO:tensorflow:train RMSE = 0.538605
# INFO:tensorflow:test RMSE = 1.037132
# INFO:tensorflow:train MAE = 0.395050
# INFO:tensorflow:test MAE = 0.803879
#
# Evaluating..:  49 / 100
# INFO:tensorflow:train RMSE = 0.538480
# INFO:tensorflow:test RMSE = 1.037327
# INFO:tensorflow:train MAE = 0.394909
# INFO:tensorflow:test MAE = 0.804073
#
# Evaluating..:  50 / 100
# INFO:tensorflow:train RMSE = 0.538361
# INFO:tensorflow:test RMSE = 1.037515
# INFO:tensorflow:train MAE = 0.394777
# INFO:tensorflow:test MAE = 0.804251
#
# Evaluating..:  51 / 100
# INFO:tensorflow:train RMSE = 0.538248
# INFO:tensorflow:test RMSE = 1.037695
# INFO:tensorflow:train MAE = 0.394652
# INFO:tensorflow:test MAE = 0.804435
#
# Evaluating..:  52 / 100
# INFO:tensorflow:train RMSE = 0.538140
# INFO:tensorflow:test RMSE = 1.037868
# INFO:tensorflow:train MAE = 0.394536
# INFO:tensorflow:test MAE = 0.804617
#
# Evaluating..:  53 / 100
# INFO:tensorflow:train RMSE = 0.538037
# INFO:tensorflow:test RMSE = 1.038035
# INFO:tensorflow:train MAE = 0.394426
# INFO:tensorflow:test MAE = 0.804794
#
# Evaluating..:  54 / 100
# INFO:tensorflow:train RMSE = 0.537939
# INFO:tensorflow:test RMSE = 1.038195
# INFO:tensorflow:train MAE = 0.394323
# INFO:tensorflow:test MAE = 0.804962
#
# Evaluating..:  55 / 100
# INFO:tensorflow:train RMSE = 0.537844
# INFO:tensorflow:test RMSE = 1.038349
# INFO:tensorflow:train MAE = 0.394223
# INFO:tensorflow:test MAE = 0.805117
#
# Evaluating..:  56 / 100
# INFO:tensorflow:train RMSE = 0.537753
# INFO:tensorflow:test RMSE = 1.038498
# INFO:tensorflow:train MAE = 0.394128
# INFO:tensorflow:test MAE = 0.805267
#
# Evaluating..:  57 / 100
# INFO:tensorflow:train RMSE = 0.537665
# INFO:tensorflow:test RMSE = 1.038641
# INFO:tensorflow:train MAE = 0.394037
# INFO:tensorflow:test MAE = 0.805418
#
# Evaluating..:  58 / 100
# INFO:tensorflow:train RMSE = 0.537581
# INFO:tensorflow:test RMSE = 1.038779
# INFO:tensorflow:train MAE = 0.393949
# INFO:tensorflow:test MAE = 0.805572
#
# Evaluating..:  59 / 100
# INFO:tensorflow:train RMSE = 0.537499
# INFO:tensorflow:test RMSE = 1.038913
# INFO:tensorflow:train MAE = 0.393865
# INFO:tensorflow:test MAE = 0.805716
#
# Evaluating..:  60 / 100
# INFO:tensorflow:train RMSE = 0.537420
# INFO:tensorflow:test RMSE = 1.039043
# INFO:tensorflow:train MAE = 0.393783
# INFO:tensorflow:test MAE = 0.805858
#
# Evaluating..:  61 / 100
# INFO:tensorflow:train RMSE = 0.537343
# INFO:tensorflow:test RMSE = 1.039169
# INFO:tensorflow:train MAE = 0.393705
# INFO:tensorflow:test MAE = 0.806001
#
# Evaluating..:  62 / 100
# INFO:tensorflow:train RMSE = 0.537269
# INFO:tensorflow:test RMSE = 1.039291
# INFO:tensorflow:train MAE = 0.393629
# INFO:tensorflow:test MAE = 0.806140
#
# Evaluating..:  63 / 100
# INFO:tensorflow:train RMSE = 0.537196
# INFO:tensorflow:test RMSE = 1.039410
# INFO:tensorflow:train MAE = 0.393557
# INFO:tensorflow:test MAE = 0.806277
#
# Evaluating..:  64 / 100
# INFO:tensorflow:train RMSE = 0.537126
# INFO:tensorflow:test RMSE = 1.039525
# INFO:tensorflow:train MAE = 0.393486
# INFO:tensorflow:test MAE = 0.806411
#
# Evaluating..:  65 / 100
# INFO:tensorflow:train RMSE = 0.537057
# INFO:tensorflow:test RMSE = 1.039638
# INFO:tensorflow:train MAE = 0.393417
# INFO:tensorflow:test MAE = 0.806541
#
# Evaluating..:  66 / 100
# INFO:tensorflow:train RMSE = 0.536990
# INFO:tensorflow:test RMSE = 1.039748
# INFO:tensorflow:train MAE = 0.393352
# INFO:tensorflow:test MAE = 0.806663
#
# Evaluating..:  67 / 100
# INFO:tensorflow:train RMSE = 0.536925
# INFO:tensorflow:test RMSE = 1.039855
# INFO:tensorflow:train MAE = 0.393288
# INFO:tensorflow:test MAE = 0.806779
#
# Evaluating..:  68 / 100
# INFO:tensorflow:train RMSE = 0.536861
# INFO:tensorflow:test RMSE = 1.039960
# INFO:tensorflow:train MAE = 0.393226
# INFO:tensorflow:test MAE = 0.806898
#
# Evaluating..:  69 / 100
# INFO:tensorflow:train RMSE = 0.536799
# INFO:tensorflow:test RMSE = 1.040063
# INFO:tensorflow:train MAE = 0.393166
# INFO:tensorflow:test MAE = 0.807013
#
# Evaluating..:  70 / 100
# INFO:tensorflow:train RMSE = 0.536738
# INFO:tensorflow:test RMSE = 1.040163
# INFO:tensorflow:train MAE = 0.393109
# INFO:tensorflow:test MAE = 0.807130
#
# Evaluating..:  71 / 100
# INFO:tensorflow:train RMSE = 0.536679
# INFO:tensorflow:test RMSE = 1.040261
# INFO:tensorflow:train MAE = 0.393053
# INFO:tensorflow:test MAE = 0.807237
#
# Evaluating..:  72 / 100
# INFO:tensorflow:train RMSE = 0.536621
# INFO:tensorflow:test RMSE = 1.040358
# INFO:tensorflow:train MAE = 0.392998
# INFO:tensorflow:test MAE = 0.807337
#
# Evaluating..:  73 / 100
# INFO:tensorflow:train RMSE = 0.536564
# INFO:tensorflow:test RMSE = 1.040452
# INFO:tensorflow:train MAE = 0.392944
# INFO:tensorflow:test MAE = 0.807432
#
# Evaluating..:  74 / 100
# INFO:tensorflow:train RMSE = 0.536509
# INFO:tensorflow:test RMSE = 1.040545
# INFO:tensorflow:train MAE = 0.392891
# INFO:tensorflow:test MAE = 0.807523
#
# Evaluating..:  75 / 100
# INFO:tensorflow:train RMSE = 0.536455
# INFO:tensorflow:test RMSE = 1.040635
# INFO:tensorflow:train MAE = 0.392840
# INFO:tensorflow:test MAE = 0.807606
#
# Evaluating..:  76 / 100
# INFO:tensorflow:train RMSE = 0.536402
# INFO:tensorflow:test RMSE = 1.040725
# INFO:tensorflow:train MAE = 0.392788
# INFO:tensorflow:test MAE = 0.807679
#
# Evaluating..:  77 / 100
# INFO:tensorflow:train RMSE = 0.536350
# INFO:tensorflow:test RMSE = 1.040812
# INFO:tensorflow:train MAE = 0.392738
# INFO:tensorflow:test MAE = 0.807749
#
# Evaluating..:  78 / 100
# INFO:tensorflow:train RMSE = 0.536300
# INFO:tensorflow:test RMSE = 1.040898
# INFO:tensorflow:train MAE = 0.392688
# INFO:tensorflow:test MAE = 0.807818
#
# Evaluating..:  79 / 100
# INFO:tensorflow:train RMSE = 0.536252
# INFO:tensorflow:test RMSE = 1.040983
# INFO:tensorflow:train MAE = 0.392640
# INFO:tensorflow:test MAE = 0.807888
#
# Evaluating..:  80 / 100
# INFO:tensorflow:train RMSE = 0.536204
# INFO:tensorflow:test RMSE = 1.041066
# INFO:tensorflow:train MAE = 0.392594
# INFO:tensorflow:test MAE = 0.807955
#
# Evaluating..:  81 / 100
# INFO:tensorflow:train RMSE = 0.536158
# INFO:tensorflow:test RMSE = 1.041148
# INFO:tensorflow:train MAE = 0.392550
# INFO:tensorflow:test MAE = 0.808022
#
# Evaluating..:  82 / 100
# INFO:tensorflow:train RMSE = 0.536113
# INFO:tensorflow:test RMSE = 1.041229
# INFO:tensorflow:train MAE = 0.392506
# INFO:tensorflow:test MAE = 0.808086
#
# Evaluating..:  83 / 100
# INFO:tensorflow:train RMSE = 0.536069
# INFO:tensorflow:test RMSE = 1.041308
# INFO:tensorflow:train MAE = 0.392463
# INFO:tensorflow:test MAE = 0.808147
#
# Evaluating..:  84 / 100
# INFO:tensorflow:train RMSE = 0.536027
# INFO:tensorflow:test RMSE = 1.041386
# INFO:tensorflow:train MAE = 0.392420
# INFO:tensorflow:test MAE = 0.808203
#
# Evaluating..:  85 / 100
# INFO:tensorflow:train RMSE = 0.535985
# INFO:tensorflow:test RMSE = 1.041463
# INFO:tensorflow:train MAE = 0.392378
# INFO:tensorflow:test MAE = 0.808254
#
# Evaluating..:  86 / 100
# INFO:tensorflow:train RMSE = 0.535945
# INFO:tensorflow:test RMSE = 1.041538
# INFO:tensorflow:train MAE = 0.392338
# INFO:tensorflow:test MAE = 0.808304
#
# Evaluating..:  87 / 100
# INFO:tensorflow:train RMSE = 0.535906
# INFO:tensorflow:test RMSE = 1.041613
# INFO:tensorflow:train MAE = 0.392298
# INFO:tensorflow:test MAE = 0.808345
#
# Evaluating..:  88 / 100
# INFO:tensorflow:train RMSE = 0.535868
# INFO:tensorflow:test RMSE = 1.041686
# INFO:tensorflow:train MAE = 0.392260
# INFO:tensorflow:test MAE = 0.808380
#
# Evaluating..:  89 / 100
# INFO:tensorflow:train RMSE = 0.535831
# INFO:tensorflow:test RMSE = 1.041759
# INFO:tensorflow:train MAE = 0.392224
# INFO:tensorflow:test MAE = 0.808410
#
# Evaluating..:  90 / 100
# INFO:tensorflow:train RMSE = 0.535795
# INFO:tensorflow:test RMSE = 1.041830
# INFO:tensorflow:train MAE = 0.392189
# INFO:tensorflow:test MAE = 0.808434
#
# Evaluating..:  91 / 100
# INFO:tensorflow:train RMSE = 0.535761
# INFO:tensorflow:test RMSE = 1.041901
# INFO:tensorflow:train MAE = 0.392154
# INFO:tensorflow:test MAE = 0.808454
#
# Evaluating..:  92 / 100
# INFO:tensorflow:train RMSE = 0.535727
# INFO:tensorflow:test RMSE = 1.041970
# INFO:tensorflow:train MAE = 0.392120
# INFO:tensorflow:test MAE = 0.808477
#
# Evaluating..:  93 / 100
# INFO:tensorflow:train RMSE = 0.535694
# INFO:tensorflow:test RMSE = 1.042038
# INFO:tensorflow:train MAE = 0.392087
# INFO:tensorflow:test MAE = 0.808508
#
# Evaluating..:  94 / 100
# INFO:tensorflow:train RMSE = 0.535662
# INFO:tensorflow:test RMSE = 1.042106
# INFO:tensorflow:train MAE = 0.392053
# INFO:tensorflow:test MAE = 0.808541
#
# Evaluating..:  95 / 100
# INFO:tensorflow:train RMSE = 0.535631
# INFO:tensorflow:test RMSE = 1.042173
# INFO:tensorflow:train MAE = 0.392021
# INFO:tensorflow:test MAE = 0.808572
#
# Evaluating..:  96 / 100
# INFO:tensorflow:train RMSE = 0.535601
# INFO:tensorflow:test RMSE = 1.042239
# INFO:tensorflow:train MAE = 0.391991
# INFO:tensorflow:test MAE = 0.808603
#
# Evaluating..:  97 / 100
# INFO:tensorflow:train RMSE = 0.535572
# INFO:tensorflow:test RMSE = 1.042305
# INFO:tensorflow:train MAE = 0.391962
# INFO:tensorflow:test MAE = 0.808632
#
# Evaluating..:  98 / 100
# INFO:tensorflow:train RMSE = 0.535543
# INFO:tensorflow:test RMSE = 1.042370
# INFO:tensorflow:train MAE = 0.391934
# INFO:tensorflow:test MAE = 0.808659
#
# Evaluating..:  99 / 100
# INFO:tensorflow:train RMSE = 0.535515
# INFO:tensorflow:test RMSE = 1.042434
# INFO:tensorflow:train MAE = 0.391907
# INFO:tensorflow:test MAE = 0.808686

# %%
sess.close()
